# %%
### import math.exp as exp 

#Coefficients for equation of state
n1 = 0.136097243686983*(10**-2)
n2 = 0.107028500555504
n3 = -0.243926251659031*10
n4 = 0.341240789637052*(10**2)
n5 = -0.422956791527436*(10**4)
n6 = 0.105277159433708*(10**-3)
n7 = -0.111355267180312*(10**-1)
n8 = 0.142748464727047*(10**-3)
n9 = 0.179621096187021*(10**5)
n10 = 0.751267113751007*(10**-7)
n11 = 0.231737284741220*(10**-2)
n12 = -0.509008258448481
n13 = 0.488523311385766*(10**-4)
n14 = -0.112001704676209*(10**-2)
n15 = -0.678366343173806
n16 = 0.742796115735318*(10**-4)
n17 = -0.110400310752087*(10**-5)
n18 = 0.341309483327025*(10**-3)
n19 = -0.166216790652177*(10**-5)
n20 = -0.164616585853003*(10**5)
n21 = -0.119724198386865*(10**6)
n22 = -0.948085610750225*(10**2)
n23 = 0.554879602331972*(10**5)
n24 = -0.174677685666810
n25 = -0.256709963280944*10
n26 = -0.404528219006087*(10**-3)
n27 = -0.257279422571519
n28 = -0.121204517440575*(10**-6)
n29 = 0.104690038752288*(10**-4)
n30 = -0.529499586313775*(10**-9)
n31 = -0.774723053052639*(10**-8)
n32 = 0.610368224362452*(10**-7)

r = 11.21 #rho in terms of mol/liter #rho critical value
R = 0.08205 #ideal gas law constant in L*atm/mol*K
g = #gamma value
T = 70 #temperature in K

P = rRT+(r**2)*(n1*T+n2*(T**(1/2))+n3+(n4/T)+(n5/(T**2)))+(r**3)*(n6*T+n7+(n8/T)+(n9/(T**2)))+(r**4)*(n10*T+n11+(n12/T))+(r**5)*(n13)+(r**6)*((n14/T)+(n15/(T**2)))+(r**7)*(n16/T)+(r**8)*((n17/T)+(n18/(T**2)))+(r**9)*(n19/(T**2))+(r**3)*((n20/(T**2))+(n21/(T**3)))*exp(-g*(r**2))+(r**5)*((n22/(T**2))+(n23/(T**4)))*exp(-g*(r**2))+(r**7)*((n24/(T**2))+(n25/(T**3)))*exp(g*(r**2))+(r**9)*((n26/(T**2))+(n27/(T**4)))*exp(-g*(r**2))+(r**11)*((n28/(T**2))+(n27/(T**4)))*exp(-g*(r**2))+(r**13)*((n30/(T**2))+(n31/(T**3))+(n32/(T**4)))*exp(-g*(r**2))
